# %% [markdown]
# #### Import

# %%
from ipynb.fs.full.preprocessOne import train_ds, val_ds, test_ds, NUM_CLASSES
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, Model
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# #### Initialize Model (EfficientNetB0)

# %%
myNetB0 = EfficientNetB0(
    include_top=False, # Using my own labels (I think that is what this does)
    weights="imagenet",
    input_shape=(224,224,3) # Image Size
)

myNetB0.trainable = False # Stops previous traning weights from leaking into this new task

# I literally have no idea what is happening here ----------------------------------
x = layers.GlobalAveragePooling2D()(myNetB0.output)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.3)(x)
output = layers.Dense(NUM_CLASSES, activation="softmax", name="flower_type")(x)
# ----------------------------------------------------------------------------------

myModelFixed = Model(inputs=myNetB0.input, outputs=output)

myModelFixed.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",  # checks how much the model got wrong (changed from catergorical to sparse)
    metrics=["accuracy"] # Judges who to decide what the model got right
)

# %% [markdown]
# #### Callbacks

# %%
callbacks = [
    # Stop early if val_loss stops improving
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=5, # If no improvement after 5 epochs, stops
        restore_best_weights=True
    ),
    # Reduce learning rate when val_loss plateaus
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        min_lr=1e-6
    ),
    # Save the best model to disk
    tf.keras.callbacks.ModelCheckpoint(
        "best_model.keras",
        monitor="val_accuracy",
        save_best_only=True
    )
]

# %% [markdown]
# #### Training

# %%
history = myModelFixed.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 44s 381ms/step - accuracy: 0.2082 - loss: 2.1486 - val_accuracy: 0.2284 - val_loss: 1.6094 - learning_rate: 0.0010
# Epoch 2/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.2122 - loss: 2.0548 - val_accuracy: 0.1744 - val_loss: 1.6089 - learning_rate: 0.0010
# Epoch 3/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.2029 - loss: 1.8855 - val_accuracy: 0.3194 - val_loss: 1.6038 - learning_rate: 0.0010
# Epoch 4/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 368ms/step - accuracy: 0.2327 - loss: 1.7474 - val_accuracy: 0.2052 - val_loss: 1.6065 - learning_rate: 0.0010
# Epoch 5/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 367ms/step - accuracy: 0.2360 - loss: 1.6796 - val_accuracy: 0.2546 - val_loss: 1.6063 - learning_rate: 0.0010
# Epoch 6/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - accuracy: 0.2420 - loss: 1.6559 - val_accuracy: 0.2284 - val_loss: 1.6059 - learning_rate: 0.0010
# Epoch 7/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.2380 - loss: 1.6266 - val_accuracy: 0.2531 - val_loss: 1.6065 - learning_rate: 5.0000e-04
# Epoch 8/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 33s 346ms/step - accuracy: 0.2453 - loss: 1.6240 - val_accuracy: 0.2593 - val_loss: 1.6045 - learning_rate: 5.0000e-04

# %% [markdown]
# #### Graph Epochs (AI)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
fig.patch.set_facecolor("#0F1117")

epochs = range(1, len(history.history["accuracy"]) + 1)

for ax in (ax1, ax2):
    ax.set_facecolor("#0F1117")
    ax.yaxis.grid(True, color="#2A2D3A", linewidth=0.8, zorder=0)
    ax.set_axisbelow(True)
    for spine in ax.spines.values():
        spine.set_visible(False)
    ax.tick_params(colors="#6B7280")

# --- Accuracy ---
ax1.plot(epochs, history.history["accuracy"],     color="#4C9BE8", label="Train Accuracy")
ax1.plot(epochs, history.history["val_accuracy"], color="#E8834C", label="Val Accuracy", linestyle="--")
ax1.set_title("Accuracy per Epoch",  color="white", fontsize=14, fontweight="bold", pad=15)
ax1.set_xlabel("Epoch",              color="#9CA3AF", fontsize=11)
ax1.set_ylabel("Accuracy",           color="#9CA3AF", fontsize=11)
ax1.legend(facecolor="#1C1F2E", edgecolor="none", labelcolor="white")

# --- Loss ---
ax2.plot(epochs, history.history["loss"],     color="#4C9BE8", label="Train Loss")
ax2.plot(epochs, history.history["val_loss"], color="#E8834C", label="Val Loss", linestyle="--")
ax2.set_title("Loss per Epoch",  color="white", fontsize=14, fontweight="bold", pad=15)
ax2.set_xlabel("Epoch",          color="#9CA3AF", fontsize=11)
ax2.set_ylabel("Loss",           color="#9CA3AF", fontsize=11)
ax2.legend(facecolor="#1C1F2E", edgecolor="none", labelcolor="white")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Fine Tuning

# %%
# Unfreeze the base model
myModelFixed.layers[0].trainable = True

# Recompile with a much lower learning rate
myModelFixed.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history_finetune = myModelFixed.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 45s 397ms/step - accuracy: 0.2211 - loss: 1.7971 - val_accuracy: 0.3164 - val_loss: 1.6012 - learning_rate: 1.0000e-05
# Epoch 2/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 381ms/step - accuracy: 0.2320 - loss: 1.7287 - val_accuracy: 0.3164 - val_loss: 1.5973 - learning_rate: 1.0000e-05
# Epoch 3/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 369ms/step - accuracy: 0.2546 - loss: 1.6722 - val_accuracy: 0.3148 - val_loss: 1.5910 - learning_rate: 1.0000e-05
# Epoch 4/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.2267 - loss: 1.6793 - val_accuracy: 0.3426 - val_loss: 1.5858 - learning_rate: 1.0000e-05
# Epoch 5/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 374ms/step - accuracy: 0.2393 - loss: 1.6755 - val_accuracy: 0.3364 - val_loss: 1.5820 - learning_rate: 1.0000e-05
# Epoch 6/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.2476 - loss: 1.6674 - val_accuracy: 0.3395 - val_loss: 1.5823 - learning_rate: 1.0000e-05
# Epoch 7/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.2360 - loss: 1.6710 - val_accuracy: 0.3333 - val_loss: 1.5821 - learning_rate: 1.0000e-05
# Epoch 8/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 378ms/step - accuracy: 0.2403 - loss: 1.6547 - val_accuracy: 0.3287 - val_loss: 1.5826 - learning_rate: 1.0000e-05
# Epoch 9/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 369ms/step - accuracy: 0.2430 - loss: 1.6609 - val_accuracy: 0.3364 - val_loss: 1.5820 - learning_rate: 5.0000e-06
# Epoch 10/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 378ms/step - accuracy: 0.2340 - loss: 1.6520 - val_accuracy: 0.3472 - val_loss: 1.5824 - learning_rate: 5.0000e-06
# Epoch 11/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 373ms/step - accuracy: 0.2324 - loss: 1.6620 - val_accuracy: 0.3457 - val_loss: 1.5832 - learning_rate: 5.0000e-06
# Epoch 12/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 380ms/step - accuracy: 0.2486 - loss: 1.6386 - val_accuracy: 0.3441 - val_loss: 1.5825 - learning_rate: 2.5000e-06
# Epoch 13/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 54s 565ms/step - accuracy: 0.2254 - loss: 1.6566 - val_accuracy: 0.3457 - val_loss: 1.5839 - learning_rate: 2.5000e-06
# Epoch 14/20
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.2403 - loss: 1.6515 - val_accuracy: 0.3472 - val_loss: 1.5836 - learning_rate: 2.5000e-06

# %% [markdown]
# #### Graph Epochs of Tuned Model

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
fig.patch.set_facecolor("#0F1117")

epochs = range(1, len(history_finetune.history["accuracy"]) + 1)

for ax in (ax1, ax2):
    ax.set_facecolor("#0F1117")
    ax.yaxis.grid(True, color="#2A2D3A", linewidth=0.8, zorder=0)
    ax.set_axisbelow(True)
    for spine in ax.spines.values():
        spine.set_visible(False)
    ax.tick_params(colors="#6B7280")

# --- Accuracy ---
ax1.plot(epochs, history_finetune.history["accuracy"],     color="#4C9BE8", label="Train Accuracy")
ax1.plot(epochs, history_finetune.history["val_accuracy"], color="#E8834C", label="Val Accuracy", linestyle="--")
ax1.set_title("Accuracy per Epoch",  color="white", fontsize=14, fontweight="bold", pad=15)
ax1.set_xlabel("Epoch",              color="#9CA3AF", fontsize=11)
ax1.set_ylabel("Accuracy",           color="#9CA3AF", fontsize=11)
ax1.legend(facecolor="#1C1F2E", edgecolor="none", labelcolor="white")

# --- Loss ---
ax2.plot(epochs, history_finetune.history["loss"],     color="#4C9BE8", label="Train Loss")
ax2.plot(epochs, history_finetune.history["val_loss"], color="#E8834C", label="Val Loss", linestyle="--")
ax2.set_title("Loss per Epoch",  color="white", fontsize=14, fontweight="bold", pad=15)
ax2.set_xlabel("Epoch",          color="#9CA3AF", fontsize=11)
ax2.set_ylabel("Loss",           color="#9CA3AF", fontsize=11)
ax2.legend(facecolor="#1C1F2E", edgecolor="none", labelcolor="white")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Evaluate on Test Set

# %%
test_loss, test_accuracy = myModelFixed.evaluate(test_ds)
print(f"Test Loss:     {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 283ms/step - accuracy: 0.2639 - loss: 1.6012
# Test Loss:     1.6012
# Test Accuracy: 0.2639
